# %%
from utils.dataset import Dataset
import numpy as np
import pandas as pd

# %%
dfc = Dataset('data.csv')

# %%
subs = dfc.df_open_times - dfc.df_send_times.values
subs = dfc.df_open_times + (dfc.df_open_times[subs < 0] - dfc.df_open_times[subs < 0] + 24).fillna(0)
new = subs - dfc.df_send_times.values
new
# Out:
#             TO00       TO01       TO02       TO03       TO04       TO05  \
# 0       8.450000  20.616667  20.650000  18.966667  20.783333   3.450000
# 1       0.183333   0.000000   0.000000   0.000000   0.000000   0.000000
# 2      14.366667   0.000000   0.000000   0.000000   0.000000   0.000000
# 3       0.633333   1.066667   0.000000   0.000000   0.000000   0.000000
# 4       7.983333   6.016667   8.783333   1.716667   5.700000  10.033333
# ...          ...        ...        ...        ...        ...        ...
# 99995   0.616667   0.000000   0.250000   0.000000   0.000000   0.000000
# 99996   0.266667   0.083333   1.700000   0.016667   0.166667   0.800000
# 99997   0.016667   0.400000   0.816667   0.200000   0.500000   2.800000
# 99998   2.116667  13.766667   0.550000   5.283333   0.000000   0.000000
# 99999  20.900000  20.266667   0.000000   0.000000   0.000000   0.000000
#
#             TO06      TO07      TO08       TO09       TO10       TO11  TO12  \
# ...
